# %% [markdown]
# # Problem statement 12:
# Scan the dataset and give the inference as:
# 1. List down the features and their types (e.g., numeric, nominal) available in the dataset.
# 2. Create a histogram for each feature in the dataset to illustrate the feature distributions.
# 3. Create a box plot for each feature in the dataset.
# 4. Compare distributions and identify outliers.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = sns.load_dataset("iris")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
len(df)
# Out:
# 150

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# 1. List down the features and their types (e.g., numeric, nominal) available in the dataset.

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
numeric_columns = set(df._get_numeric_data().columns)

# %%
print("Numeric Columns: ", numeric_columns)
# Out:
# Numeric Columns:  {'petal_length', 'sepal_width', 'petal_width', 'sepal_length'}

# %%
ordinal_columns = set(df.columns) - numeric_columns

# %%
ordinal_columns
# Out:
# {'species'}

# %% [markdown]
# 2. Create a histogram for each feature in the dataset to illustrate the feature distributions.

# %%
sns.histplot(df)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(data=df, x="sepal_length")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data=df, x="sepal_width")
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(data=df, x='petal_length')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(data=df, x="petal_width")
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='Count'>

# %%
sns.histplot(data=df.loc[df['species']=="setosa"], x="sepal_length")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data=df.loc[df["species"]=="setosa"], x="sepal_width")
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(data=df.loc[df["species"]=="setosa"], x="petal_length")
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(data=df.loc[df["species"]=="setosa"], x="petal_width")
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='Count'>

# %%
sns.histplot(data=df.loc[df["species"]=="versicolor"], x="sepal_length")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data=df.loc[df["species"]=="versicolor"], x="sepal_width")
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(data=df.loc[df["species"]=="versicolor"], x="petal_length")
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(data=df.loc[df["species"]=="versicolor"], x="petal_width")
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='Count'>

# %%
sns.histplot(data=df.loc[df["species"]=="virginica"], x="sepal_length")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data=df.loc[df["species"]=="virginica"], x="sepal_width")
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(data=df.loc[df["species"]=="virginica"], x="petal_length")
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(data=df.loc[df["species"]=="virginica"], x="petal_width")
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='Count'>

# %% [markdown]
# 3. Create a box plot for each feature in the dataset.

# %%
sns.boxplot(data=df, x="sepal_length")
# Out:
# <AxesSubplot:xlabel='sepal_length'>

# %%
sns.boxplot(data=df, x="sepal_width")
# Out:
# <AxesSubplot:xlabel='sepal_width'>

# %%
sns.boxplot(data=df, x="petal_length")
# Out:
# <AxesSubplot:xlabel='petal_length'>

# %%
sns.boxplot(data=df, x="petal_width")
# Out:
# <AxesSubplot:xlabel='petal_width'>

# %%
sns.boxplot(data=df, x="sepal_length", y="species")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='species'>

# %%
sns.boxplot(data=df, x="sepal_width", y="species")
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='species'>

# %%
sns.boxplot(data=df, x="petal_length", y="species")
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='species'>

# %%
sns.boxplot(data=df, x="petal_width", y="species")
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='species'>
